# %% [markdown]
# <a href="https://colab.research.google.com/github/crisalexps/Challange-Alura-Store/blob/main/tiendaAlexa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Practicando**

# %% [markdown]
# ## **Tiendas de Juan**

# %% [markdown]
# # Nueva sección

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

# %%
total=tienda["Precio"].sum()
print(total)

total1=tienda2["Precio"].sum()
print(total1)
total2=tienda3["Precio"].sum()
print(total2)
total3=tienda4["Precio"].sum()
print(total3)

#variable = nombretabla ["nombrecolumna"].funcion_de_agregacion()
# Out:
# 1150880400.0
# 1116343500.0
# 1098019600.0
# 1038375700.0

# %%
producto_por_cat_t1=tienda.groupby('Categoría del Producto').size()
print(producto_por_cat_t1)
print("\n")
producto_por_cat_t2=tienda2.groupby('Categoría del Producto').size()
print(producto_por_cat_t2)
print("\n")
producto_por_cat_t3=tienda3.groupby('Categoría del Producto').size()
print(producto_por_cat_t3)
print("\n")
producto_por_cat_t4=tienda4.groupby('Categoría del Producto').size()
print(producto_por_cat_t4)
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# dtype: int64
#
#
# Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# dtype: int64
#
#
# Categoría del Producto
# Artículos para el hogar    177
# Deportes y diversión       277
# Electrodomésticos          278
# Electrónicos               451
# Instrumentos musicales     177
# Juguetes                   315
# Libros                     185
# Muebles                    499
# dtype: int64
#
#
# Categoría del Producto
# Artículos para el hogar    201
# ...

# %%
cant1=tienda["Calificación"].sum()
#print(cant1)
num=tienda["Calificación"].count()
#print(num)
res=cant1/num
print(res)
# Out:
# 3.976685036032217

# %%
cant=tienda2["Calificación"].sum()
#print(cant)
num=tienda2["Calificación"].count()
#print(num)
res=cant/num
print(res)
# Out:
# 4.037303942348453

# %%
cant=tienda3["Calificación"].sum()
#print(cant)
num=tienda3["Calificación"].count()
#print(num)
res=cant/num
print(res)
# Out:
# 4.048325561678677

# %%
cant=tienda4["Calificación"].sum()
#print(cant)
num=tienda4["Calificación"].count()
#print(num)
res=cant/num
print(res)
# Out:
# 3.9957591178965224

# %%
prod_max_t1=tienda["Producto"].max()
print(prod_max_t1)
prod_min_t1=tienda["Producto"].min()
print(prod_min_t1)
# Out:
# Vaso térmico
# Ajedrez de madera

# %%
prod_max_t2=tienda["Producto"].max()
print(prod_max_t2)
prod_min_t2=tienda["Producto"].min()
print(prod_min_t2)
# Out:
# Vaso térmico
# Ajedrez de madera

# %%
prod_max_tienda3=tienda3["Producto"].max()
print(prod_max_tienda3)
prod_min_tienda3=tienda3["Producto"].min()
print(prod_min_tienda3)
# Out:
# Vaso térmico
# Ajedrez de madera

# %%
prod_max_t4=tienda4["Producto"].max()
print(prod_max_t4)
prod_min_t4=tienda4["Producto"].min()
print(prod_min_t4)
# Out:
# Vaso térmico
# Ajedrez de madera

# %%
Costo_envío_pagado=tienda["Costo de envío"]
suma_Costo =sum(Costo_envío_pagado)
cantidad_envío =len(Costo_envío_pagado)
promedio_envío = suma_Costo / cantidad_envío

print(f"El promedio de envío es: {promedio_envío}")
# Out:
# El promedio de envío es: 26018.60958033065

# %%
Costo_envío_pagado=tienda2["Costo de envío"]
suma_Costo =sum(Costo_envío_pagado)
cantidad_envío =len(Costo_envío_pagado)
promedio_envío = suma_Costo / cantidad_envío

print(f"El promedio de envío es: {promedio_envío}")
# Out:
# El promedio de envío es: 25216.235693090293

# %%
Costo_envío_pagado=tienda3["Costo de envío"]
suma_Costo =sum(Costo_envío_pagado)
cantidad_envío =len(Costo_envío_pagado)
promedio_envío = suma_Costo / cantidad_envío

print(f"El promedio de envío es: {promedio_envío}")
# Out:
# El promedio de envío es: 24805.680373039424

# %%
Costo_envío_pagado=tienda4["Costo de envío"]
suma_Costo =sum(Costo_envío_pagado)
cantidad_envío =len(Costo_envío_pagado)
promedio_envío = suma_Costo / cantidad_envío

print(f"El promedio de envío es: {promedio_envío}")
# Out:
# El promedio de envío es: 23459.457167090754

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
producto_por_cat_t1=tienda.groupby('Categoría del Producto').size()

producto_por_cat_t1.plot(kind='line',figsize=(8,6),color='skyblue',xlabel='Categoría del Producto',ylabel='Cantidad')
plt.title('Cantidad de Productos por Categoría')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
producto_por_cat_t2=tienda2.groupby('Lugar de Compra').size()

producto_por_cat_t2.plot(kind='bar',figsize=(10,5),color='pink',xlabel='Lugar de Compra',ylabel='Cantidad')
plt.title('Cantidad de Productos por Lugar de Compra')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
labels='Tienda_1','Tienda_2','Tienda_3','Tienda_4'
sizes=[1150880400,1116343500, 1098019600, 1038375700]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
ax.set_title('Total de Importe de Ventas por Tienda')
# Out:
# Text(0.5, 1.0, 'Total de Importe de Ventas por Tienda')
